# %% [markdown]
# # Feature Engineering

# %%
import sys
sys.path.insert(0, '..')

from src.dataset import load_or_create_dataset
from src.feature_engineering import add_engineered_features, select_model_features

df = load_or_create_dataset()
engineered = add_engineered_features(df)
select_model_features(engineered)
