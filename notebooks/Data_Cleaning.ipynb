# %% [markdown]
# # Data Cleaning
#
# Load raw data, inspect quality, and apply cleaning steps.

# %%
import sys
sys.path.insert(0, '..')

from src.dataset import load_or_create_dataset
from src.preprocessing import clean_data, preprocess_and_save

df = load_or_create_dataset()
df.head()

# %%
cleaned = clean_data(df)
preprocess_and_save()
cleaned.describe()
